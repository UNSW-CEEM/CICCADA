# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# # 1. Loading

# %%
folder = Path(r"C:\Users\z3553082\OneDrive - UNSW\Documents\CICCADA - Data\solar edge\OneDrive_1_6-18-2026\data_2025_01_12_alias_zipped")

files = list(folder.glob("*.parquet"))
df = pd.concat((pd.read_parquet(f) for f in files), ignore_index=True)

df.head()
# Out:
#   site_alias                   timestamp  active_power_1  active_power_2  \
# 0     AUS001  2025-01-18 10:56:00.000000      331.495239             NaN
# 1     AUS001  2025-01-18 11:01:00.000000      358.739594             NaN
# 2     AUS001  2025-01-18 11:06:00.000000      399.047180             NaN
# 3     AUS001  2025-01-18 11:11:00.000000      307.645752             NaN
# 4     AUS001  2025-01-18 11:16:00.000000      588.053894             NaN
#
#    active_power_3  reactive_power_1  reactive_power_2  reactive_power_3  \
# 0             NaN        133.485626               NaN               NaN
# 1             NaN        149.324783               NaN               NaN
# 2             NaN        149.562119               NaN               NaN
# 3             NaN        138.304642               NaN               NaN
# 4             NaN        150.843155               NaN               NaN
#
#    ac_voltage_1  ac_voltage_2  ac_voltage_3  ac_frequency_1  ac_frequency_2  \
# 0    243.767776           NaN           NaN       49.964836             NaN
# 1    244.220245           NaN           NaN       49.974575             NaN
# 2    244.007385           NaN           NaN       49.972515             NaN
# 3    244.569519           NaN           NaN       50.030102             NaN
# 4    246.198456           NaN           NaN       49.972744             NaN
#
#    ac_frequency_3  derating_active_flag
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN

# %%
files
# Out:
# [WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_01_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_02_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_03_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_04_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_05_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_06_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_07_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_08_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_09_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_10_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_11_alias_zipped (1).parquet'),
#  WindowsPath('C:/Users/z3553082/OneDrive - UNSW/Documents/CICCADA - Data/solar edge/OneDrive_1_6-18-2026/data_2025_01_12_alias_zipped/data_2025_12_alias_zipped (1).parquet')]

# %%
alias_path = Path(r"C:\Users\z3553082\OneDrive - UNSW\Documents\CICCADA - Data\solar edge\OneDrive_1_6-18-2026\alias_mapping_alias_only.csv")

alias_df = pd.read_csv(alias_path)   # or read all parquet files if it's a folder
df = df.merge(
    alias_df[["alias", "zip_code"]],
    left_on="site_alias",
    right_on="alias",
    how="left"
)

df.head()
# Out:
#   site_alias                   timestamp  active_power_1  active_power_2  \
# 0     AUS001  2025-01-18 10:56:00.000000      331.495239             NaN
# 1     AUS001  2025-01-18 11:01:00.000000      358.739594             NaN
# 2     AUS001  2025-01-18 11:06:00.000000      399.047180             NaN
# 3     AUS001  2025-01-18 11:11:00.000000      307.645752             NaN
# 4     AUS001  2025-01-18 11:16:00.000000      588.053894             NaN
#
#    active_power_3  reactive_power_1  reactive_power_2  reactive_power_3  \
# 0             NaN        133.485626               NaN               NaN
# 1             NaN        149.324783               NaN               NaN
# 2             NaN        149.562119               NaN               NaN
# 3             NaN        138.304642               NaN               NaN
# 4             NaN        150.843155               NaN               NaN
#
#    ac_voltage_1  ac_voltage_2  ac_voltage_3  ac_frequency_1  ac_frequency_2  \
# 0    243.767776           NaN           NaN       49.964836             NaN
# 1    244.220245           NaN           NaN       49.974575             NaN
# 2    244.007385           NaN           NaN       49.972515             NaN
# 3    244.569519           NaN           NaN       50.030102             NaN
# 4    246.198456           NaN           NaN       49.972744             NaN
#
#    ac_frequency_3  derating_active_flag   alias  zip_code
# 0             NaN                   NaN  AUS001      2291
# 1             NaN                   NaN  AUS001      2291
# 2             NaN                   NaN  AUS001      2291
# 3             NaN                   NaN  AUS001      2291
# 4             NaN                   NaN  AUS001      2291

# %%
df
# Out:
#          site_alias                   timestamp  active_power_1  \
# 0            AUS001  2025-01-18 10:56:00.000000      331.495239
# 1            AUS001  2025-01-18 11:01:00.000000      358.739594
# 2            AUS001  2025-01-18 11:06:00.000000      399.047180
# 3            AUS001  2025-01-18 11:11:00.000000      307.645752
# 4            AUS001  2025-01-18 11:16:00.000000      588.053894
# ...             ...                         ...             ...
# 86643180     AUS572  2025-12-14 18:41:04.000000        0.000000
# 86643181     AUS572  2025-12-14 18:46:04.000000        0.000000
# 86643182     AUS572  2025-12-14 18:51:04.000000        0.000000
# 86643183     AUS572  2025-12-14 18:56:04.000000        0.000000
# 86643184     AUS572  2025-12-14 20:56:05.000000        0.000000
#
#           active_power_2  active_power_3  reactive_power_1  reactive_power_2  \
# 0                    NaN             NaN        133.485626               NaN
# 1                    NaN             NaN        149.324783               NaN
# 2                    NaN             NaN        149.562119               NaN
# 3                    NaN             NaN        138.304642               NaN
# 4                    NaN             NaN        150.843155               NaN
# ...                  ...             ...               ...               ...
# 86643180             NaN             NaN       -240.229630               NaN
# 86643181             NaN             NaN          0.000000               NaN
# 86643182             NaN             NaN          0.000000               NaN
# 86643183             NaN             NaN          0.000000               NaN
# 86643184             NaN             NaN          0.000000               NaN
#
#           reactive_power_3  ac_voltage_1  ac_voltage_2  ac_voltage_3  \
# 0                      NaN    243.767776           NaN           NaN
# 1                      NaN    244.220245           NaN           NaN
# 2                      NaN    244.007385           NaN           NaN
# 3                      NaN    244.569519           NaN           NaN
# 4                      NaN    246.198456           NaN           NaN
# ...                    ...           ...           ...           ...
# 86643180               NaN    234.029938           NaN           NaN
# 86643181               NaN    231.819016           NaN           NaN
# 86643182               NaN    232.835556           NaN           NaN
# 86643183               NaN    232.526825           NaN           NaN
# 86643184               NaN    238.569626           NaN           NaN
#
#           ac_frequency_1  ac_frequency_2  ac_frequency_3  \
# 0              49.964836             NaN             NaN
# 1              49.974575             NaN             NaN
# 2              49.972515             NaN             NaN
# 3              50.030102             NaN             NaN
# 4              49.972744             NaN             NaN
# ...                  ...             ...             ...
# 86643180       49.985718             NaN             NaN
# 86643181       49.976238             NaN             NaN
# 86643182       50.005142             NaN             NaN
# 86643183       50.008038             NaN             NaN
# 86643184       50.015503             NaN             NaN
#
#           derating_active_flag   alias  zip_code
# 0                          NaN  AUS001      2291
# 1                          NaN  AUS001      2291
# 2                          NaN  AUS001      2291
# 3                          NaN  AUS001      2291
# 4                          NaN  AUS001      2291
# ...                        ...     ...       ...
# 86643180                   NaN  AUS572      4869
# 86643181                   NaN  AUS572      4869
# 86643182                   NaN  AUS572      4869
# 86643183                   NaN  AUS572      4869
# 86643184                   NaN  AUS572      4869
#
# [86643185 rows x 17 columns]

# %% [markdown]
# # 2.

# %%
site_id = "AUS908"

# 3phase:
site_id = "AUS631"

# single phase (raw sign fits)
site_id = "AUS515"

# single phase (flipped sign fits)
# site_id = "AUS352"

# single phase:
# site_id = "AUS1569"

test_site = df[df['site_alias'] == site_id]

# %%
test_site
# Out:
#          site_alias                   timestamp  active_power_1  \
# 43024        AUS515  2025-01-22 06:16:19.000000        0.000000
# 43025        AUS515  2025-01-22 06:21:19.000000        0.000000
# 43026        AUS515  2025-01-22 06:26:19.000000        0.000000
# 43027        AUS515  2025-01-22 06:31:19.000000        0.000000
# 43028        AUS515  2025-01-22 06:36:19.000000        0.000000
# ...             ...                         ...             ...
# 86612045     AUS515  2025-12-24 10:06:21.000000     2433.558594
# 86612046     AUS515  2025-12-24 10:11:21.000000     2470.253906
# 86612047     AUS515  2025-12-24 10:16:21.000000     2551.429443
# 86612048     AUS515  2025-12-24 10:21:21.000000     2689.819580
# 86612049     AUS515  2025-12-24 10:26:21.000000     2766.014404
#
#           active_power_2  active_power_3  reactive_power_1  reactive_power_2  \
# 43024                NaN             NaN          0.000000               NaN
# 43025                NaN             NaN          0.000000               NaN
# 43026                NaN             NaN          0.000000               NaN
# 43027                NaN             NaN       -110.274643               NaN
# 43028                NaN             NaN          0.000000               NaN
# ...                  ...             ...               ...               ...
# 86612045             NaN             NaN      -1042.791260               NaN
# 86612046             NaN             NaN       -947.288574               NaN
# 86612047             NaN             NaN      -1421.808594               NaN
# 86612048             NaN             NaN      -1456.989014               NaN
# 86612049             NaN             NaN      -1370.191650               NaN
#
#           reactive_power_3  ac_voltage_1  ac_voltage_2  ac_voltage_3  \
# 43024                  NaN    245.077805           NaN           NaN
# 43025                  NaN    245.083939           NaN           NaN
# 43026                  NaN    244.295380           NaN           NaN
# 43027                  NaN    244.975037           NaN           NaN
# 43028                  NaN    242.664032           NaN           NaN
# ...                    ...           ...           ...           ...
# 86612045               NaN    246.422318           NaN           NaN
# 86612046               NaN    246.856476           NaN           NaN
# 86612047               NaN    248.539795           NaN           NaN
# 86612048               NaN    248.709305           NaN           NaN
# 86612049               NaN    248.019714           NaN           NaN
#
#           ac_frequency_1  ac_frequency_2  ac_frequency_3  \
# 43024          50.015087             NaN             NaN
# 43025          50.019413             NaN             NaN
# 43026          50.022526             NaN             NaN
# 43027          50.025867             NaN             NaN
# 43028          49.977718             NaN             NaN
# ...                  ...             ...             ...
# 86612045       49.957737             NaN             NaN
# 86612046       49.969292             NaN             NaN
# 86612047       50.019196             NaN             NaN
# 86612048       49.980843             NaN             NaN
# 86612049       49.947109             NaN             NaN
#
#           derating_active_flag   alias  zip_code
# 43024                      NaN  AUS515      5352
# 43025                      NaN  AUS515      5352
# 43026                      NaN  AUS515      5352
# 43027                      NaN  AUS515      5352
# 43028                      NaN  AUS515      5352
# ...                        ...     ...       ...
# 86612045                   NaN  AUS515      5352
# 86612046                   NaN  AUS515      5352
# 86612047                   NaN  AUS515      5352
# 86612048                   NaN  AUS515      5352
# 86612049                   NaN  AUS515      5352
#
# [55441 rows x 17 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# pick the day you want
selected_date = pd.Timestamp("2025-07-22") 

start = selected_date.normalize()
end = start + pd.Timedelta(days=1)

day_site = df[(df["site_alias"] == site_id) &
              (pd.to_datetime(df["timestamp"]) >= start) &
              (pd.to_datetime(df["timestamp"]) < end)].copy()

day_site["timestamp"] = pd.to_datetime(day_site["timestamp"])
day_site = day_site.sort_values("timestamp")

day_site["active_power_total"] = day_site[["active_power_1", "active_power_2", "active_power_3"]].sum(axis=1)
day_site["reactive_power_total"] = day_site[["reactive_power_1", "reactive_power_2", "reactive_power_3"]].sum(axis=1)
day_site["voltage_avg"] = day_site[["ac_voltage_1", "ac_voltage_2", "ac_voltage_3"]].mean(axis=1)

# Apparent power and power factor for phase 1
# S = sqrt(P^2 + Q^2)
day_site["apparent_power_1"] = (day_site["active_power_1"]**2 + day_site["reactive_power_1"]**2) ** 0.5
# PF = P / S
day_site["power_factor_1"] = day_site["active_power_1"] / day_site["apparent_power_1"]

fig, axes = plt.subplots(3, 1, sharex=True, figsize=(14, 11))

day_site.plot(x="timestamp", y="active_power_total", ax=axes[0], legend=False, color="tab:blue")
axes[0].set_title(f"Active power for {site_id} on {start:%Y-%m-%d}")
axes[0].set_ylabel("Active power")
axes[0].grid(True, alpha=0.3)

day_site.plot(x="timestamp", y="reactive_power_total", ax=axes[1], legend=False, color="tab:orange")
axes[1].set_title("Reactive power")
axes[1].set_ylabel("Reactive power")
axes[1].grid(True, alpha=0.3)

day_site.plot(x="timestamp", y="voltage_avg", ax=axes[2], legend=False, color="tab:green")
axes[2].set_title("Average AC voltage")
axes[2].set_ylabel("Voltage")
axes[2].grid(True, alpha=0.3)

axes[2].xaxis.set_major_locator(mdates.HourLocator(interval=1))
axes[2].xaxis.set_major_formatter(mdates.DateFormatter("%H:%M"))
plt.setp(axes[2].get_xticklabels(), rotation=45)

plt.tight_layout()

# %%
day_site
# Out:
#          site_alias           timestamp  active_power_1  active_power_2  \
# 42576160     AUS515 2025-07-22 05:16:19             0.0             NaN
# 42576161     AUS515 2025-07-22 07:11:19             0.0             NaN
# 42576162     AUS515 2025-07-22 07:16:19             0.0             NaN
# 42576163     AUS515 2025-07-22 07:21:19             0.0             NaN
# 42576164     AUS515 2025-07-22 07:26:19             0.0             NaN
# ...             ...                 ...             ...             ...
# 41723576     AUS515 2025-07-22 17:26:19             0.0             NaN
# 41723577     AUS515 2025-07-22 17:31:19             0.0             NaN
# 41723578     AUS515 2025-07-22 17:36:19             0.0             NaN
# 41723579     AUS515 2025-07-22 17:41:19             0.0             NaN
# 41723580     AUS515 2025-07-22 19:41:20             0.0             NaN
#
#           active_power_3  reactive_power_1  reactive_power_2  \
# 42576160             NaN          0.000000               NaN
# 42576161             NaN          0.000000               NaN
# 42576162             NaN          0.000000               NaN
# 42576163             NaN          0.000000               NaN
# 42576164             NaN       -102.550026               NaN
# ...                  ...               ...               ...
# 41723576             NaN         97.558121               NaN
# 41723577             NaN          0.000000               NaN
# 41723578             NaN          0.000000               NaN
# 41723579             NaN          0.000000               NaN
# 41723580             NaN          0.000000               NaN
#
#           reactive_power_3  ac_voltage_1  ac_voltage_2  ...  ac_frequency_2  \
# 42576160               NaN    238.825684           NaN  ...             NaN
# 42576161               NaN    242.700821           NaN  ...             NaN
# 42576162               NaN    241.011093           NaN  ...             NaN
# 42576163               NaN    239.961884           NaN  ...             NaN
# 42576164               NaN    243.261047           NaN  ...             NaN
# ...                    ...           ...           ...  ...             ...
# 41723576               NaN    236.993347           NaN  ...             NaN
# 41723577               NaN    238.245758           NaN  ...             NaN
# 41723578               NaN    239.196411           NaN  ...             NaN
# 41723579               NaN    237.730713           NaN  ...             NaN
# 41723580               NaN    238.525497           NaN  ...             NaN
#
#           ac_frequency_3  derating_active_flag   alias  zip_code  \
# 42576160             NaN                   NaN  AUS515      5352
# 42576161             NaN                   NaN  AUS515      5352
# 42576162             NaN                   NaN  AUS515      5352
# 42576163             NaN                   NaN  AUS515      5352
# 42576164             NaN                   NaN  AUS515      5352
# ...                  ...                   ...     ...       ...
# 41723576             NaN                   NaN  AUS515      5352
# 41723577             NaN                   NaN  AUS515      5352
# 41723578             NaN                   NaN  AUS515      5352
# 41723579             NaN                   NaN  AUS515      5352
# 41723580             NaN                   NaN  AUS515      5352
#
#          active_power_total  reactive_power_total  voltage_avg  \
# 42576160                0.0              0.000000   238.825684
# 42576161                0.0              0.000000   242.700821
# 42576162                0.0              0.000000   241.011093
# 42576163                0.0              0.000000   239.961884
# 42576164                0.0           -102.550026   243.261047
# ...                     ...                   ...          ...
# 41723576                0.0             97.558121   236.993347
# 41723577                0.0              0.000000   238.245758
# 41723578                0.0              0.000000   239.196411
# 41723579                0.0              0.000000   237.730713
# 41723580                0.0              0.000000   238.525497
#
#           apparent_power_1  power_factor_1
# 42576160          0.000000             NaN
# 42576161          0.000000             NaN
# 42576162          0.000000             NaN
# 42576163          0.000000             NaN
# 42576164        102.550026             0.0
# ...                    ...             ...
# 41723576         97.558121             0.0
# 41723577          0.000000             NaN
# 41723578          0.000000             NaN
# 41723579          0.000000             NaN
# 41723580          0.000000             NaN
#
# [129 rows x 22 columns]

# %%
# Apparent power and power factor for phase 1
# S = sqrt(P^2 + Q^2)
day_site["apparent_power_1"] = (day_site["active_power_1"]**2 + day_site["reactive_power_1"]**2) ** 0.5

# PF = P / S
day_site["power_factor_1"] = day_site["active_power_1"] / day_site["apparent_power_1"]

# %%
plot_df = day_site[["timestamp", "active_power_1", "reactive_power_1", "apparent_power_1", "power_factor_1"]].copy()
plot_df["timestamp"] = pd.to_datetime(plot_df["timestamp"])
plot_df = plot_df.sort_values("timestamp")

fig, axes = plt.subplots(4, 1, sharex=True, figsize=(14, 12))

for col, ax in zip(["active_power_1", "reactive_power_1", "apparent_power_1", "power_factor_1"], axes):
    plot_df.plot(x="timestamp", y=col, ax=ax, legend=False)
    ax.set_ylabel(col.replace("_", " ").title())
    ax.grid(True, alpha=0.3)

axes[-1].set_xlabel("Timestamp")
plt.tight_layout()
